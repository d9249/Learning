# %%
import numpy as np
import os
from os import listdir
from os.path import isfile, join
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

np.random.seed(3)
 
datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15, 
#     shear_range = 0.5,
    width_shift_range = 0.05,
    height_shift_range = 0.1,
    zoom_range = 0,
#     horizontal_flip=True,
#     vertical_flip=True,
    fill_mode = 'nearest'
    ) 
 
 
filename_in_dir = []
filename = []

for root, dirs, files in os.walk('c:\\Users\\dodo9\\Downloads\\aug_knee_data\\validation\\4'):
    for fname in files:
        filename.append(fname)
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)
    
for file_image in filename_in_dir:
    print(file_image)
    img = load_img(file_image) 
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x,save_to_dir='c:\\Users\\dodo9\\Downloads\\aug_knee_data\\validation\\4_validation', save_prefix='aug_4', save_format='jpg'):
        i += 1
        if i > 99:
            break
# Out:
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a249aa1e4b0f1e9e5628635.dcm_left.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a332e22e4b06f4ed3afa24f.dcm_left.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a332e22e4b06f4ed3afa24f.dcm_right.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a443ed5e4b028f6847218e9.dcm_right.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a444a81e4b06f4ed3b3ef49.dcm_left.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a444a81e4b06f4ed3b3ef49.dcm_right.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a46d638e4b06f4ed3b4b42f.dcm_left.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a62a732e4b05b48a5337c83.dcm_right.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a750c0ee4b05b48a539d1f0.dcm_left.jpg
# c:\Users\dodo9\Downloads\aug_knee_data\validation\4\5a750c0ee4b05b48a539d1f0.dcm_right.jpg
# ...
