# %% [markdown]
# <a href="https://colab.research.google.com/github/d9249/DACON/blob/main/squeezenet1_0%20Train%2BInference%20(ImageNet%20statistics%2C%20pretrained%2C%20full).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun Oct 10 03:11:32 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/DACON_2021_recognize_traffic_signal_motion/new_open.zip" -d "/content/"

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import torch, torchvision
import torchvision.transforms as transforms
import os, json, PIL
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
import numpy as np
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split

# %%
def count(output, target):
    with torch.no_grad():
        predict = torch.argmax(output, 1)
        correct = (predict == target).sum().item()
        return correct

def select_model(model, num_classes):
    if model == 'resnet18':
        model_ = models.resnet18(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet34':
        model_ = models.cc(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'resnet50':
        model_ = models.resnet50(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet101':
        model_ = models.resnet101(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'resnet152':
        model_ = models.resnet152(pretrained=True)
        model_.fc = nn.Linear(2048, num_classes)
    elif model == 'densenet121':
        model_ = models.densenet121(pretrained=True)
        model_.classifier = nn.Linear(1024, num_classes)
    elif model == 'densenet169':
        model_ = models.densenet169(pretrained=True)
        model_.classifier = nn.Linear(1664, num_classes)
    elif model == 'densenet201':
        model_ = models.densenet201(pretrained=True)
        model_.classifier = nn.Linear(1920, num_classes)
    elif model == 'densenet161':
        model_ = models.densenet161(pretrained=True)
        model_.classifier = nn.Linear(2208, num_classes)
    elif model == 'inception_v3':
        model_ = models.inception_v3(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'googlenet':
        model_ = models.googlenet(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'shufflenet_v2_x1_0':
        model_ = models.shufflenet_v2_x1_0(pretrained=True)
        model_.fc = nn.Linear(1024, num_classes)
    elif model == 'alexnet':
        model_ = models.alexnet(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'squeezenet1_0':
        model_ = models.squeezenet1_0(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Dropout(p=0.5, inplace=False),
            nn.Conv2d(512, num_classes, kernel_size=(1, 1), stride=(1, 1)),
            nn.ReLU(inplace=True),
            nn.AdaptiveAvgPool2d(output_size=(1, 1)),
        )
    elif model == 'squeezenet1_1':
        model_ = models.squeezenet1_1(pretrained=True)
        model_.fc = nn.Linear(512, num_classes)
    elif model == 'vgg11':
        model_ = models.vgg11(pretrained=True)
        model_.classifier = nn.Sequential(
            nn.Linear(in_features=25088, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(in_features=4096, out_features=4096, bias=True),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.5, inplace=False),
            nn.Linear(4096, num_classes, bias=True),
        )
    elif model == 'vgg13':
        model_ = models.vgg13(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg16':
        model_ = models.vgg16(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    elif model == 'vgg19':
        model_ = models.vgg19(pretrained=True)
        model_.classifier = nn.Linear(25088, num_classes)
    return model_

class Baseline():
    def __init__(self, model, num_classes, gpu_id=0, epoch_print=1, print_freq=10, save=False):
        self.gpu = gpu_id
        self.epoch_print = epoch_print
        self.print_freq = print_freq
        self.save = save

        torch.cuda.set_device(self.gpu)

        self.loss_function = nn.CrossEntropyLoss().cuda(self.gpu)

        model = select_model(model, num_classes)
        self.model = model.cuda(self.gpu)

        self.train_losses, self.test_losses = [], []
        self.train_acc, self.test_acc = [], []
        self.best_acc = None
        self.best_loss = None

    def train(self, train_data, test_data, epochs=100, lr=0.1, weight_decay=0.0001):
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr, weight_decay=weight_decay)
        
        for epoch in range(epochs):
            if epoch % self.epoch_print == 0: print('Epoch {} Started...'.format(epoch+1))
            for i, (X, y) in enumerate(train_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)
                loss = self.loss_function(output, y)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                if (epoch % self.epoch_print == 0) and (i % self.print_freq == 0):
                    train_acc = 100 * count(output, y) / y.size(0)
                    test_acc, test_loss = self.test(test_data)
                    
                    if self.save and ((self.best_acc == None) or (self.best_acc < test_acc) or (test_loss < self.best_loss)):
                        torch.save(self.model.state_dict(), '{}_{}.pt'.format(epoch, i))
                        self.best_acc = test_acc
                        self.best_loss = test_loss
                        print('Best Model Saved')

                    self.train_losses.append(loss.item())
                    self.train_acc.append(train_acc)
                    self.test_losses.append(test_loss)
                    self.test_acc.append(test_acc)

                    print('Iteration : {} - Train Loss : {:.6f}, Test Loss : {:.6f}, '
                          'Train Acc : {:.6f}, Test Acc : {:.6f}'.format(i+1, loss.item(), test_loss, train_acc, test_acc))
            print()

    def test(self, test_data):
        correct, total = 0, 0
        losses = []

        self.model.eval()
        with torch.no_grad():
            for i, (X, y) in enumerate(test_data):
                X, y = X.cuda(self.gpu), y.cuda(self.gpu)
                output = self.model(X)

                loss = self.loss_function(output, y)
                losses.append(loss.item())
                
                correct += count(output, y)
                total += y.size(0)
        self.model.train()
        return (100*correct/total, sum(losses)/len(losses))

# %%
data_dir = './train/'
imgs, labels = [], []
for num in sorted(os.listdir(data_dir)):
    with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
        temp = json.load(j)
        for info in temp['annotations']:
            imgs.append(data_dir + '{}/{}.png'.format(num, info['image_id']))
            labels.append(temp['action'][0])

label_info = {label:i for i, label in enumerate(sorted(set(labels)))}
train_imgs, val_imgs, train_labels, val_labels = train_test_split(imgs, labels, random_state=0, stratify=labels)

class TrainDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = train_imgs
        self.labels = train_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)
    
class ValDataset(Dataset):
    def __init__(self, transform=None):
        self.imgs = val_imgs
        self.labels = val_labels
        self.label_info = label_info
        self.transform = transform

    def __getitem__(self, idx):
        img = PIL.Image.open(self.imgs[idx]).convert('RGB')
        if self.transform: img = self.transform(img)

        label = self.label_info[self.labels[idx]]
        return img, label

    def __len__(self):
        return len(self.imgs)

# %%
batch_size = 32

train_transform = transforms.Compose([
    transforms.Resize(256), transforms.RandomCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

val_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

# %%
train_dataset = TrainDataset(transform=train_transform)
val_dataset = ValDataset(transform=val_transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
model = Baseline(model='squeezenet1_0', num_classes=len(train_dataset.label_info), print_freq=5, save=True)
# Out:
# Downloading: "https://download.pytorch.org/models/squeezenet1_0-b66bff10.pth" to /root/.cache/torch/hub/checkpoints/squeezenet1_0-b66bff10.pth
#   0%|          | 0.00/4.78M [00:00<?, ?B/s]

# %%
len(train_dataset.label_info)
# Out:
# 157

# %%
epochs = 5
lr = 0.0005
weight_decay = 0.00001

# %%
model.train(train_loader, val_loader, epochs=epochs, lr=lr, weight_decay=weight_decay)
# Out:
# Epoch 1 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 5.382153, Test Loss : 5.091392, Train Acc : 0.000000, Test Acc : 0.747283
# Best Model Saved
# Iteration : 6 - Train Loss : 5.062876, Test Loss : 5.053841, Train Acc : 0.000000, Test Acc : 1.154891
# Iteration : 11 - Train Loss : 5.062405, Test Loss : 5.057321, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 16 - Train Loss : 5.049728, Test Loss : 5.052653, Train Acc : 0.000000, Test Acc : 0.951087
# Best Model Saved
# Iteration : 21 - Train Loss : 5.052509, Test Loss : 5.049555, Train Acc : 0.000000, Test Acc : 0.475543
# Best Model Saved
# Iteration : 26 - Train Loss : 5.058033, Test Loss : 5.047390, Train Acc : 0.000000, Test Acc : 0.883152
# Best Model Saved
# Iteration : 31 - Train Loss : 5.069126, Test Loss : 5.040283, Train Acc : 0.000000, Test Acc : 1.154891
# Best Model Saved
# Iteration : 36 - Train Loss : 5.039369, Test Loss : 5.037546, Train Acc : 3.125000, Test Acc : 1.494565
# Best Model Saved
# Iteration : 41 - Train Loss : 5.058981, Test Loss : 5.025561, Train Acc : 0.000000, Test Acc : 0.679348
# Best Model Saved
# Iteration : 46 - Train Loss : 5.019307, Test Loss : 5.023720, Train Acc : 3.125000, Test Acc : 2.105978
# Best Model Saved
# Iteration : 51 - Train Loss : 5.041399, Test Loss : 5.000918, Train Acc : 0.000000, Test Acc : 1.426630
# Best Model Saved
# Iteration : 56 - Train Loss : 4.952946, Test Loss : 4.953374, Train Acc : 0.000000, Test Acc : 1.562500
# Iteration : 61 - Train Loss : 4.957346, Test Loss : 5.003585, Train Acc : 0.000000, Test Acc : 1.019022
# Best Model Saved
# Iteration : 66 - Train Loss : 4.921164, Test Loss : 4.923481, Train Acc : 0.000000, Test Acc : 1.766304
# Best Model Saved
# Iteration : 71 - Train Loss : 5.072087, Test Loss : 4.899920, Train Acc : 3.125000, Test Acc : 1.970109
# Best Model Saved
# Iteration : 76 - Train Loss : 4.910660, Test Loss : 4.878619, Train Acc : 3.125000, Test Acc : 1.698370
# Best Model Saved
# Iteration : 81 - Train Loss : 5.081026, Test Loss : 4.847116, Train Acc : 3.125000, Test Acc : 1.834239
# Best Model Saved
# Iteration : 86 - Train Loss : 4.794070, Test Loss : 4.839819, Train Acc : 0.000000, Test Acc : 1.630435
# Best Model Saved
# Iteration : 91 - Train Loss : 4.888152, Test Loss : 4.823863, Train Acc : 0.000000, Test Acc : 1.902174
# Iteration : 96 - Train Loss : 4.761738, Test Loss : 4.824696, Train Acc : 0.000000, Test Acc : 1.834239
# Best Model Saved
# Iteration : 101 - Train Loss : 4.791301, Test Loss : 4.760960, Train Acc : 6.250000, Test Acc : 1.630435
# Best Model Saved
# Iteration : 106 - Train Loss : 4.906197, Test Loss : 4.778535, Train Acc : 0.000000, Test Acc : 2.241848
# Iteration : 111 - Train Loss : 4.646673, Test Loss : 4.782687, Train Acc : 3.125000, Test Acc : 1.426630
# Best Model Saved
# Iteration : 116 - Train Loss : 4.773975, Test Loss : 4.759813, Train Acc : 0.000000, Test Acc : 1.630435
# Best Model Saved
# Iteration : 121 - Train Loss : 4.748171, Test Loss : 4.693107, Train Acc : 3.125000, Test Acc : 2.105978
# Iteration : 126 - Train Loss : 4.584259, Test Loss : 4.705112, Train Acc : 3.125000, Test Acc : 1.630435
# Best Model Saved
# Iteration : 131 - Train Loss : 4.696795, Test Loss : 4.619147, Train Acc : 3.125000, Test Acc : 1.426630
# Best Model Saved
# Iteration : 136 - Train Loss : 4.833318, Test Loss : 4.596707, Train Acc : 0.000000, Test Acc : 2.513587
#
# Epoch 2 Started...
# Iteration : 1 - Train Loss : 4.492035, Test Loss : 4.624068, Train Acc : 3.125000, Test Acc : 2.173913
# Iteration : 6 - Train Loss : 4.751317, Test Loss : 4.622494, Train Acc : 0.000000, Test Acc : 2.173913
# Best Model Saved
# Iteration : 11 - Train Loss : 4.582682, Test Loss : 4.599167, Train Acc : 6.250000, Test Acc : 2.717391
# Best Model Saved
# Iteration : 16 - Train Loss : 4.640121, Test Loss : 4.604399, Train Acc : 3.125000, Test Acc : 3.804348
# Best Model Saved
# Iteration : 21 - Train Loss : 4.538508, Test Loss : 4.559566, Train Acc : 0.000000, Test Acc : 2.649457
# Best Model Saved
# Iteration : 26 - Train Loss : 4.560457, Test Loss : 4.553638, Train Acc : 0.000000, Test Acc : 2.513587
# Best Model Saved
# Iteration : 31 - Train Loss : 4.593815, Test Loss : 4.479721, Train Acc : 3.125000, Test Acc : 2.853261
# Best Model Saved
# Iteration : 36 - Train Loss : 4.293189, Test Loss : 4.430673, Train Acc : 6.250000, Test Acc : 3.736413
# Best Model Saved
# Iteration : 41 - Train Loss : 4.132859, Test Loss : 4.394157, Train Acc : 6.250000, Test Acc : 4.551630
# Best Model Saved
# Iteration : 46 - Train Loss : 4.480077, Test Loss : 4.388285, Train Acc : 3.125000, Test Acc : 4.483696
# Best Model Saved
# Iteration : 51 - Train Loss : 4.484295, Test Loss : 4.333931, Train Acc : 3.125000, Test Acc : 5.095109
# Iteration : 56 - Train Loss : 4.232913, Test Loss : 4.374883, Train Acc : 3.125000, Test Acc : 3.736413
# Best Model Saved
# Iteration : 61 - Train Loss : 4.018318, Test Loss : 4.275702, Train Acc : 6.250000, Test Acc : 4.823370
# Best Model Saved
# Iteration : 66 - Train Loss : 4.152215, Test Loss : 4.229882, Train Acc : 3.125000, Test Acc : 5.095109
# Best Model Saved
# Iteration : 71 - Train Loss : 3.911249, Test Loss : 4.202700, Train Acc : 12.500000, Test Acc : 5.027174
# Best Model Saved
# Iteration : 76 - Train Loss : 4.128709, Test Loss : 4.176671, Train Acc : 12.500000, Test Acc : 6.182065
# Best Model Saved
# Iteration : 81 - Train Loss : 3.643783, Test Loss : 4.106328, Train Acc : 15.625000, Test Acc : 7.880435
# Best Model Saved
# Iteration : 86 - Train Loss : 4.186513, Test Loss : 4.029527, Train Acc : 6.250000, Test Acc : 6.317935
# Best Model Saved
# Iteration : 91 - Train Loss : 4.163161, Test Loss : 4.006725, Train Acc : 3.125000, Test Acc : 7.948370
# Best Model Saved
# Iteration : 96 - Train Loss : 4.013082, Test Loss : 3.956456, Train Acc : 9.375000, Test Acc : 10.122283
# Best Model Saved
# Iteration : 101 - Train Loss : 3.965840, Test Loss : 3.949103, Train Acc : 0.000000, Test Acc : 8.220109
# Best Model Saved
# Iteration : 106 - Train Loss : 4.049967, Test Loss : 3.875871, Train Acc : 9.375000, Test Acc : 6.929348
# Best Model Saved
# Iteration : 111 - Train Loss : 3.839398, Test Loss : 3.746033, Train Acc : 9.375000, Test Acc : 12.160326
# Best Model Saved
# Iteration : 116 - Train Loss : 3.621313, Test Loss : 3.730496, Train Acc : 12.500000, Test Acc : 10.869565
# Best Model Saved
# Iteration : 121 - Train Loss : 4.112827, Test Loss : 3.714964, Train Acc : 6.250000, Test Acc : 9.510870
# Best Model Saved
# Iteration : 126 - Train Loss : 3.541416, Test Loss : 3.780509, Train Acc : 15.625000, Test Acc : 11.073370
# Best Model Saved
# Iteration : 131 - Train Loss : 3.884053, Test Loss : 3.700408, Train Acc : 3.125000, Test Acc : 11.684783
# Best Model Saved
# Iteration : 136 - Train Loss : 3.565176, Test Loss : 3.677536, Train Acc : 12.500000, Test Acc : 10.665761
#
# Epoch 3 Started...
# Best Model Saved
# Iteration : 1 - Train Loss : 3.809279, Test Loss : 3.708468, Train Acc : 6.250000, Test Acc : 11.141304
# Best Model Saved
# Iteration : 6 - Train Loss : 3.558142, Test Loss : 3.706942, Train Acc : 18.750000, Test Acc : 11.684783
# Best Model Saved
# Iteration : 11 - Train Loss : 3.307669, Test Loss : 3.597536, Train Acc : 6.250000, Test Acc : 15.217391
# Best Model Saved
# Iteration : 16 - Train Loss : 3.627493, Test Loss : 3.526531, Train Acc : 15.625000, Test Acc : 12.907609
# Iteration : 21 - Train Loss : 3.403494, Test Loss : 3.570781, Train Acc : 15.625000, Test Acc : 12.500000
# Best Model Saved
# Iteration : 26 - Train Loss : 3.504523, Test Loss : 3.503815, Train Acc : 9.375000, Test Acc : 14.877717
# Best Model Saved
# Iteration : 31 - Train Loss : 3.384781, Test Loss : 3.534815, Train Acc : 18.750000, Test Acc : 15.217391
# Best Model Saved
# Iteration : 36 - Train Loss : 3.476591, Test Loss : 3.417818, Train Acc : 12.500000, Test Acc : 15.896739
# Best Model Saved
# Iteration : 41 - Train Loss : 3.232351, Test Loss : 3.365880, Train Acc : 15.625000, Test Acc : 16.100543
# Best Model Saved
# Iteration : 46 - Train Loss : 3.327835, Test Loss : 3.361654, Train Acc : 18.750000, Test Acc : 16.100543
# Iteration : 51 - Train Loss : 3.366209, Test Loss : 3.384995, Train Acc : 12.500000, Test Acc : 15.285326
# Best Model Saved
# Iteration : 56 - Train Loss : 3.254357, Test Loss : 3.222013, Train Acc : 18.750000, Test Acc : 17.866848
# Best Model Saved
# Iteration : 61 - Train Loss : 3.139047, Test Loss : 3.155375, Train Acc : 25.000000, Test Acc : 20.788043
# Best Model Saved
# Iteration : 66 - Train Loss : 3.471256, Test Loss : 3.044124, Train Acc : 18.750000, Test Acc : 22.826087
# Iteration : 71 - Train Loss : 2.906861, Test Loss : 3.045576, Train Acc : 25.000000, Test Acc : 21.603261
# Iteration : 76 - Train Loss : 3.148284, Test Loss : 3.053795, Train Acc : 15.625000, Test Acc : 21.263587
# Best Model Saved
# Iteration : 81 - Train Loss : 3.218759, Test Loss : 2.953009, Train Acc : 21.875000, Test Acc : 23.573370
# Iteration : 86 - Train Loss : 3.130473, Test Loss : 3.047613, Train Acc : 25.000000, Test Acc : 21.127717
# Iteration : 91 - Train Loss : 3.403019, Test Loss : 3.005127, Train Acc : 12.500000, Test Acc : 20.448370
# Best Model Saved
# Iteration : 96 - Train Loss : 3.298348, Test Loss : 2.982994, Train Acc : 12.500000, Test Acc : 25.611413
# Best Model Saved
# Iteration : 101 - Train Loss : 2.863380, Test Loss : 2.924804, Train Acc : 25.000000, Test Acc : 25.815217
# Iteration : 106 - Train Loss : 3.201000, Test Loss : 2.940969, Train Acc : 21.875000, Test Acc : 23.301630
# Best Model Saved
# Iteration : 111 - Train Loss : 3.187077, Test Loss : 2.912945, Train Acc : 18.750000, Test Acc : 25.339674
# Best Model Saved
# Iteration : 116 - Train Loss : 2.527481, Test Loss : 2.776441, Train Acc : 34.375000, Test Acc : 27.921196
# Best Model Saved
# Iteration : 121 - Train Loss : 3.026622, Test Loss : 2.614600, Train Acc : 18.750000, Test Acc : 30.163043
# Iteration : 126 - Train Loss : 3.013435, Test Loss : 2.819729, Train Acc : 12.500000, Test Acc : 26.358696
# Iteration : 131 - Train Loss : 2.855943, Test Loss : 2.930933, Train Acc : 18.750000, Test Acc : 24.524457
# Iteration : 136 - Train Loss : 2.872009, Test Loss : 2.902711, Train Acc : 31.250000, Test Acc : 25.339674
#
# Epoch 4 Started...
# Iteration : 1 - Train Loss : 2.499553, Test Loss : 2.684710, Train Acc : 34.375000, Test Acc : 29.415761
# Iteration : 6 - Train Loss : 2.447649, Test Loss : 2.837573, Train Acc : 34.375000, Test Acc : 25.883152
# Best Model Saved
# Iteration : 11 - Train Loss : 3.089407, Test Loss : 2.615120, Train Acc : 18.750000, Test Acc : 31.317935
# Best Model Saved
# Iteration : 16 - Train Loss : 3.024793, Test Loss : 2.598355, Train Acc : 15.625000, Test Acc : 29.415761
# Best Model Saved
# Iteration : 21 - Train Loss : 2.577892, Test Loss : 2.563554, Train Acc : 37.500000, Test Acc : 29.076087
# Best Model Saved
# Iteration : 26 - Train Loss : 3.003993, Test Loss : 2.449742, Train Acc : 18.750000, Test Acc : 34.103261
# Best Model Saved
# Iteration : 31 - Train Loss : 2.624400, Test Loss : 2.354647, Train Acc : 31.250000, Test Acc : 34.375000
# Iteration : 36 - Train Loss : 2.663274, Test Loss : 2.436307, Train Acc : 31.250000, Test Acc : 31.657609
# Best Model Saved
# Iteration : 41 - Train Loss : 2.376424, Test Loss : 2.417467, Train Acc : 37.500000, Test Acc : 34.510870
# Iteration : 46 - Train Loss : 3.308331, Test Loss : 2.424795, Train Acc : 18.750000, Test Acc : 34.307065
# Iteration : 51 - Train Loss : 2.496245, Test Loss : 2.431595, Train Acc : 40.625000, Test Acc : 31.725543
# Iteration : 56 - Train Loss : 2.554334, Test Loss : 2.471163, Train Acc : 21.875000, Test Acc : 31.114130
# Best Model Saved
# Iteration : 61 - Train Loss : 2.542774, Test Loss : 2.260966, Train Acc : 31.250000, Test Acc : 38.383152
# Best Model Saved
# Iteration : 66 - Train Loss : 2.214857, Test Loss : 2.221882, Train Acc : 46.875000, Test Acc : 38.586957
# Iteration : 71 - Train Loss : 2.503988, Test Loss : 2.304496, Train Acc : 34.375000, Test Acc : 37.228261
# Best Model Saved
# Iteration : 76 - Train Loss : 2.041756, Test Loss : 2.179139, Train Acc : 46.875000, Test Acc : 41.508152
# Best Model Saved
# Iteration : 81 - Train Loss : 2.565548, Test Loss : 2.141335, Train Acc : 25.000000, Test Acc : 39.809783
# Best Model Saved
# Iteration : 86 - Train Loss : 2.122530, Test Loss : 2.063341, Train Acc : 37.500000, Test Acc : 43.953804
# Iteration : 91 - Train Loss : 2.260826, Test Loss : 2.064054, Train Acc : 34.375000, Test Acc : 42.934783
# Best Model Saved
# Iteration : 96 - Train Loss : 2.066831, Test Loss : 2.003276, Train Acc : 43.750000, Test Acc : 41.372283
# Best Model Saved
# Iteration : 101 - Train Loss : 2.179369, Test Loss : 2.090142, Train Acc : 34.375000, Test Acc : 42.595109
# Best Model Saved
# Iteration : 106 - Train Loss : 1.603548, Test Loss : 1.926830, Train Acc : 59.375000, Test Acc : 45.176630
# Iteration : 111 - Train Loss : 1.995432, Test Loss : 2.015385, Train Acc : 46.875000, Test Acc : 40.760870
# Best Model Saved
# Iteration : 116 - Train Loss : 1.935759, Test Loss : 1.910084, Train Acc : 43.750000, Test Acc : 45.040761
# Best Model Saved
# Iteration : 121 - Train Loss : 2.069986, Test Loss : 1.908479, Train Acc : 43.750000, Test Acc : 44.361413
# Best Model Saved
# Iteration : 126 - Train Loss : 1.856564, Test Loss : 1.901194, Train Acc : 46.875000, Test Acc : 47.350543
# Iteration : 131 - Train Loss : 1.970523, Test Loss : 1.943004, Train Acc : 37.500000, Test Acc : 46.739130
# Best Model Saved
# Iteration : 136 - Train Loss : 1.812906, Test Loss : 1.790754, Train Acc : 43.750000, Test Acc : 50.407609
#
# Epoch 5 Started...
# Iteration : 1 - Train Loss : 1.561694, Test Loss : 1.817600, Train Acc : 50.000000, Test Acc : 49.388587
# Best Model Saved
# Iteration : 6 - Train Loss : 2.506598, Test Loss : 1.755509, Train Acc : 25.000000, Test Acc : 49.864130
# Iteration : 11 - Train Loss : 1.723734, Test Loss : 2.405849, Train Acc : 56.250000, Test Acc : 37.907609
# Iteration : 16 - Train Loss : 2.087771, Test Loss : 2.054961, Train Acc : 31.250000, Test Acc : 43.206522
# Best Model Saved
# Iteration : 21 - Train Loss : 1.495440, Test Loss : 1.769243, Train Acc : 56.250000, Test Acc : 50.747283
# Iteration : 26 - Train Loss : 1.882103, Test Loss : 1.831416, Train Acc : 43.750000, Test Acc : 46.263587
# Best Model Saved
# Iteration : 31 - Train Loss : 1.937174, Test Loss : 1.752252, Train Acc : 50.000000, Test Acc : 48.641304
# Best Model Saved
# Iteration : 36 - Train Loss : 1.723148, Test Loss : 1.702280, Train Acc : 46.875000, Test Acc : 50.203804
# Best Model Saved
# Iteration : 41 - Train Loss : 0.955886, Test Loss : 1.559484, Train Acc : 71.875000, Test Acc : 56.182065
# Best Model Saved
# Iteration : 46 - Train Loss : 1.251661, Test Loss : 1.483725, Train Acc : 65.625000, Test Acc : 57.540761
# Best Model Saved
# Iteration : 51 - Train Loss : 2.284954, Test Loss : 1.434465, Train Acc : 37.500000, Test Acc : 57.948370
# Iteration : 56 - Train Loss : 1.161652, Test Loss : 1.467269, Train Acc : 56.250000, Test Acc : 56.453804
# Iteration : 61 - Train Loss : 1.674201, Test Loss : 1.603776, Train Acc : 46.875000, Test Acc : 53.396739
# Iteration : 66 - Train Loss : 1.312669, Test Loss : 1.606951, Train Acc : 56.250000, Test Acc : 52.921196
# Iteration : 71 - Train Loss : 1.688714, Test Loss : 1.618411, Train Acc : 59.375000, Test Acc : 49.932065
# Iteration : 76 - Train Loss : 1.925109, Test Loss : 1.506313, Train Acc : 25.000000, Test Acc : 54.891304
# Iteration : 81 - Train Loss : 1.251534, Test Loss : 1.494631, Train Acc : 71.875000, Test Acc : 57.065217
# Best Model Saved
# Iteration : 86 - Train Loss : 1.655176, Test Loss : 1.412900, Train Acc : 59.375000, Test Acc : 57.676630
# Best Model Saved
# Iteration : 91 - Train Loss : 1.237546, Test Loss : 1.356649, Train Acc : 62.500000, Test Acc : 57.065217
# Iteration : 96 - Train Loss : 1.766713, Test Loss : 1.452412, Train Acc : 43.750000, Test Acc : 55.706522
# Best Model Saved
# Iteration : 101 - Train Loss : 1.409672, Test Loss : 1.358212, Train Acc : 53.125000, Test Acc : 59.307065
# Best Model Saved
# Iteration : 106 - Train Loss : 1.495707, Test Loss : 1.357498, Train Acc : 62.500000, Test Acc : 60.258152
# Best Model Saved
# Iteration : 111 - Train Loss : 1.137432, Test Loss : 1.357258, Train Acc : 78.125000, Test Acc : 60.326087
# Best Model Saved
# Iteration : 116 - Train Loss : 1.271536, Test Loss : 1.306657, Train Acc : 65.625000, Test Acc : 61.480978
# Best Model Saved
# Iteration : 121 - Train Loss : 1.248720, Test Loss : 1.224779, Train Acc : 53.125000, Test Acc : 64.198370
# Best Model Saved
# Iteration : 126 - Train Loss : 1.802473, Test Loss : 1.200226, Train Acc : 46.875000, Test Acc : 61.684783
# Iteration : 131 - Train Loss : 1.392765, Test Loss : 1.255162, Train Acc : 56.250000, Test Acc : 61.005435
# Iteration : 136 - Train Loss : 1.466294, Test Loss : 1.291302, Train Acc : 46.875000, Test Acc : 59.578804

# %%
label_fontsize = 25

plt.figure(figsize=(20, 10))
train_lossline, = plt.plot(model.train_losses, label='Train')
test_lossline, = plt.plot(model.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)
plt.show()

# %%
plt.figure(figsize=(20, 10))
train_accline, = plt.plot(model.train_acc, label='Train')
test_accline, = plt.plot(model.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Acc', fontsize=label_fontsize)
plt.show()

# %%
model = Baseline(model='squeezenet1_0', num_classes=157)
model.model.load_state_dict(torch.load('./4_90.pt'))
model.model.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace=True)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace=True)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Conv2d(512, 157, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace=True)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
test_transform = transforms.Compose([
    transforms.Resize(256), transforms.CenterCrop((224, 400)),
    transforms.ToTensor(), transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

data_dir = './test/'

predictions = []
with torch.no_grad():
    for num in sorted(os.listdir(data_dir)):
        with open(data_dir + '{}/{}.json'.format(num, num), 'r') as j:
            temp = json.load(j)
            imgs = []
            for info in temp['annotations']:
                img_dir = data_dir + '{}/{}.png'.format(num, info['image_id'])
                img = PIL.Image.open(img_dir).convert('RGB')
                img = test_transform(img)
                imgs.append(img)
            imgs = torch.stack(imgs).cuda()
            prediction = torch.nn.Softmax(dim=1)(model.model(imgs))
            prediction = torch.mean(prediction, dim=0)
            
            if torch.sum(prediction) != 1: print(torch.sum(prediction))
            predictions.append(prediction.cpu().numpy())

print(len(predictions))
print(len(predictions[0]))
# Out:
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# tensor(1.0000, device='cuda:0')
# 217
# 157

# %%
sample_submission = pd.read_csv('./sample_submission.csv')
sample_submission.iloc[:,1:] = predictions
sample_submission.to_csv('./squeezenet1_0_ImageNetStat_4_90_threshno.csv', index=False)

# %%
sample_submission.iloc[:,1:]
# Out:
#           Label_0       Label_1  ...     Label_194     Label_195
# 0    3.279857e-03  7.057749e-03  ...  3.422199e-05  5.033716e-06
# 1    9.656736e-04  2.040875e-03  ...  7.140623e-06  2.230837e-06
# 2    4.491444e-04  5.572600e-03  ...  1.596399e-06  2.444384e-07
# 3    4.461766e-04  6.676912e-03  ...  4.767610e-07  7.688276e-08
# 4    1.585616e-04  4.607569e-03  ...  6.773305e-08  1.224924e-08
# ..            ...           ...  ...           ...           ...
# 212  1.917289e-07  2.369697e-09  ...  1.211146e-07  4.727773e-04
# 213  2.550311e-04  8.209810e-07  ...  1.260613e-03  2.646045e-04
# 214  3.569340e-06  1.153727e-06  ...  5.835298e-01  1.012340e-05
# 215  8.507636e-06  2.290214e-06  ...  2.309813e-01  5.384863e-06
# 216  5.879489e-10  9.701197e-11  ...  1.414535e-09  5.509396e-01
#
# [217 rows x 157 columns]
