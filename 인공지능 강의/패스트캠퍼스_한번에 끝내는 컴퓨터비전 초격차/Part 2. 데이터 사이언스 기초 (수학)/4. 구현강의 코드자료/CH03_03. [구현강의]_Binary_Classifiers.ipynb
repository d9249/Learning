# %% [markdown]
# #The Graphs of Odds and Logit

# %%
import numpy as np
import tensorflow au tf

import matplotlib.pyplot as plt
plt.style.use('seaborn‘)

P_np = np.linspace(0.01, 0.99, i)
p_tf = tf.linapace(0.01, 0.99, 100)

odds_np = p_np/(i-p_np)
odds_tf = p tf/(l-p_tf)

logit_np = np.log(odds_np)
logit_tf = tf.math.log(odd_tf)

fig, axes = plt.subplots(2, 1, figsize=({15, 10),
                        sharexeTrue)

axes[0].plot(p_np, odds_tf.numpy())
axes[1].plot(p_np, logit_tf.numpy())

xticke = np.arange(0, 1.1, 0.1)

axes[0].tick_params(labelsize=15)
axes[0].set_xticks(xticks)
axes[0].set_ylabel('Odda', fontsize=20, color=‘darkblue')
axes[1].tick_params(labelsize=15)
axes[1].set_xticks(xticks)
axes[1].eet_ylabel('Logit',fontsize»20, colore'darkblue')
axes|1].set_xlabel('Probability',fontsize=20, color=‘darkblue')

# %% [markdown]
# #The Graphs of Sigmoid

# %%
import tensorflow as tf

from tensorflow.keras.layers import Activation

X = tf.linspace(-30, 30, 100)
sigmoid = Activation('sigmoid')(X)

fig,ax = plt.subplots(figsize =(10,5))
ax.plot(X.numpy(),sigmoid.numpy())

# %% [markdown]
# #Single-variate Logistic Regression Models

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense

plt.etyle.use('seaborn')

X = tf.random.normal(shape = (100,1))
dense = Dense(units = 1, activation = 'sigmoid')

Y = dense(X)
print (Y.shape)

fig, ax = plt.subplots(figsize=(7, 7))
ax.scatter(X.numpy().flatten(), Y.numpy().flatten())

# %% [markdown]
# #Multi-variate Logistic Regression Models

# %%
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense

plt.style.use('seaborn')

X = tf.random.normal(shape=(100, 5))
dense = Dense(units =1, activations sigmoid’)

Y = dense(X)
print(Y. shape)

# %% [markdown]
# #Binary Classifier with Dense Layers

# %%
import tensorflow as tf
from tensorflow.keras.models import Seqential
from tensorflow.keras.layers import Dense

model = Sequential()
model .add(Dense(units=10, activation = 'relu'))
model.add(Dense({units=5, activation = 'relu'))
model .add(Dense(units=, activation = 'sigmoid’))
