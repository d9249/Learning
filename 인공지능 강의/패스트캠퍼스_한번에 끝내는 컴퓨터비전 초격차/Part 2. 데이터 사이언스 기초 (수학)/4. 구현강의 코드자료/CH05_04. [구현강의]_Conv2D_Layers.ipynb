# %% [markdown]
# #Shape of Conv Layers

# %%
import tensorflow as tf

from tensorflow.keras.layers import Conv2D

N, n_H, n_W, n_C = 1, 28, 28, 5
n_filter = 1
k_size = 3

images = tf.random.uniform(minval=0, maxval=1,
                          shapes((N, n_H, n_W, n_C)))


conv =  Conv2D(filters =n_filter,kernel_size=k_size)

y = conv(images)

W, B = conv.get_weights()


print (image.shape)
print (W.shape)
print(B.shape)
print (y.shape)

# %% [markdown]
# # Correlation Calculation

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Conv2D

N, n_H, n_W, n_C = 1, 5, 5, 1
n_filter = 1
k_size = 3

images = tf.random.uniform(minval=0, maxval=1,
                          shapes((N, n_H, n_W, n_C)))


conv =  Conv2D(filters =n_filter,kernel_size=k_size)

y = conv(images)
print("Y(Tensorflow) : \n",y.numpy().squeeze())
W, B = conv.get_weights()

####
image = image.numpy().squeeze()
W = W.squeeze()
print(image.shape)
print (W.shape)
print(B.shape)

# %% [markdown]
# # Correlation with n-channel

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Conv2D

N, n_H, n_W, n_C = 1, 5, 5, 1
n_filter = 1
k_size = 3

images = tf.random.uniform(minval=0, maxvalel,
                          shape=((N, m_H, n_W, n_C)))

conv = Conv2D(filters=n_filter, kernel_size=k_size)

y = conv(images)
print("Y(Tensorflow): \n", y.numpy().squeeze())
W, B = conv.get_weights()

####
images = images.numpy().squeeze()
W = W.squeeze()
y_man = np.zeros(shapes(n_H - k_size + 1, n_W - k_size + 1))
for 4 in range(n_H - k_sise + 1):
  for j in range(n_W - k_size + 1):
    window = images(i : i+k_size, j : j+k_size)
      y_man(i, j) = np.sum(window*W) + B


print("Y(Manual): \n", y_man)
