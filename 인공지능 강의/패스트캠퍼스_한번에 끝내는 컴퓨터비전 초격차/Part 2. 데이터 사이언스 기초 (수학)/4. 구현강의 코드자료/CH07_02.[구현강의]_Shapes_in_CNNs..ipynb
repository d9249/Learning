# %% [markdown]
# # Shapes in the Feature Extractors

# %%
import tensorflow as tf

from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

N, n_H, n_W, nic = 32, 28, 28, 3
n_conv_filter = 5
k_size = 3
pool_size, pool_strides = 2, 2
batch_size = 32

x = tf.random.normal(shape=({N, n_H, n_W, n_c))

conv1 = Conv2D(filtersen_conv_filter, kernel_aizesk_size,
                padding=‘same’, activation='relu’)

conv1_pool = MaxPooling2D(pool_size = pool_size, strides = pool_ strides)

conv2 = Conv2D(filters = n_conv_filter, kernel_size = k_size,
              padding='same’, activatione’relu')

conv2_pool = MaxPooling2D(pool_size = pool_size, strides =pool_strides)

flatten = Flatten()

print("Input: {}\n".format(x. shape))

x = conv1(x)
W, B = convl.get_weights()
print("W/B: {}/{}".format(W.shape, B.shape))
print("After convl: {}".format(x.shape) }
x = conv1_pool(x)
print("After convl pool: ({)}".format(x.shape))

x = conv2(x)
W,B = conv2.get_weights()
print("W/B: {}/()".format(W.shape, B.shape))
print(“After conv2: {}".format(x.shape))
x = conv2_pool(x)
print("After conv2 pool: {}”.format(x.shape))

x = flatten(x)
print("After flatten: {}".format(x.shape))

# %% [markdown]
# # Shapes in the Classifier

# %%
from tensorflow.keras.layers import Dense

n_nevrons = [50, 25, 10]

densel = Dense(units=n_neurons[0], activation='relu’}
dense2 = Dense(units=n_neurons[1], activation=‘relu’)
dense3 = Dense(units=n_neurons[2], activation="softmax')

print("Input feature: {}".format(x.shape) )
x = dense1(x)
W,B = densel .get_weights()
print("W/B :{}/{}".format(W.shape,B.shape))
print("After densel: {}\n".format(x.shape))

x = dense2(x)
W,B = dense2.get_weights()

print(“W/B: {}/{)".format(W.ehape, B.shape))
print("After dense2: (}\n".format(x.shape))

x = dense3(x)
W,B = dnese3.get_weights()
print("W/B: {}/(}".format(W.shape, B.shape))
print("After dense3: {}”.format(x.shepe))

# %% [markdown]
# # Shapes in the Loss Functions

# %%
import tensorflow on tf

from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten

N, n_H, n_W, n_e = 32, 28, 28, 3
n_conv_filter = 5
k_size = 3
pool_size, pool_strides = 2, 2
batch_size = 32

x = tf.random.normal(shape=(N, n_H, n_W, n_c))

conv1 = Conv2D{f11ters =n_conv_filter,kernel_size=k_size,
              padding=‘same', activation='relu’)

convl_pool = MaxPooling2D(pool_size=pool_size, strides=pool_ strides)

conv2 = Conv2D(filters=n_conv_filter, kernel_sizs =k_size,
                padding='same’, activation = 'relu')

conv2_ pool = MaxPooling2D(pool_size=pool_size, strides =pool_strides)

flatten = Flatten()
print("Input: {}\n".format(x.shape))

x = conv1(x)
W,B = conv1.get_weights()
print("W/B: (}/{}".format(W.shape, B.shape))
print("After convl: {}".format(x.shape))
x = conv1_pool(x)
print("After conv1 pool : {}".format(x.shape))
