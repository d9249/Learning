# %% [markdown]
# # Implementation with Sequential Method

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

N, n_H, n_W, n_C = 4, 28, 28, 3
n_conv_neurons = [10, 20, 30]
n_dense_nevrons = (50, 30, 10]
k_size, padding = 3, ‘same’
pool_size, pool_strides = 2, 2

x = tf.random.normal(shapes(N, n_H, n_W, n_C))

model = Sequential()
model.add(Conv2D(filters=n_conv_neurons(0), kernel_size*k_size, padding=padding,
                activation='relu’))

model .add(MaxPooling2D(pool_size=pool_size, strides))
model.add(Flatten())

model.add(Dense(units = n_dense_neurons[0], activation = 'relu'))
modei.add()
model.add()
model .add()
model .add()
model .add()
model .add()
model .add()
model .add()

# %% [markdown]
# # Implementation with Model Sub-classing

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

class TestCNN(Model):
  def __init__(self):
    super(TestCNN, self).__init__()

    self.conv1 = Conv2D(filters=n_conv_neurons(0), kernel_size=k_size, padding=padding,
                        activation=activation)
    self.conv1_pool = MaxPooling2D(pool_size=spool_size, strides=pool_strides)
    self.conv2 = Conv2D(filters*n_conv_neurons[1], kernel_size=k_size, padding=padding,
                        activation = activation)
    self.conv2_pool = MaxPooling2D(Pool_size=pool_size,strides = pool_strides)
    self.conv3 = Conv2D(filters=n_conv_neurons(2), kernel_size=k_size, padding=padding,
                        activation=activation)
    self.conv3_pool = MaxPooling2D(pool_size=pool_size,strides = pool_strides)
    self.flatten = Flatten()
    self.dense1 = Dense(unitsen_dense_neurons[0], activationsactivation)
    self.dense2 = Dense(unitsen_dense_neurons(1}, activationeactivation)
    self.dense3 = Dense(units=n_dense_neuronsa(2)}, activation='softmax')
    def call(self, x):
      x =self.conv1(x)
      x =self.conv1_pool(x)

      x = self.conv2(x)
      x = self.conv2_pool(x)

      x = self.conv3(x)
      x = self.conv3_pool(x)
      
      x = self.flatten(x)
      x = self.densel(x)
      x = self.dense2(x)
      x = self.dense3(x)
      return x
N, n_H, n_W, n_C = 4, 28, 28, 3
n_conv_neurons = [10, 20, 30]
n_dense_nevrons = (50, 30, 10]
k_size, padding = 3, ‘same’
pool_size, pool_strides = 2, 2

x = tf.random.normal(shape = (N,n_H,n_W,N_C))
model = TestCNN()
y = model(x)

# %% [markdown]
# # Implementation with Sequential + Layer sub-classing

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer

from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Platten
from tensorflow.keras.layers import Dense

class MyConv(Layer):
  def __init_ (self, n_neuron):
    super(MyConv, self). init_ ()
    self.conv = Conv2D(filtersen_neuron, kernel_sizesk_size, padding=padding,
                        activation =activation)
    self.conv_pool = MaxPooling2D(pool_size=pool_size, strides=pool_strides)
  def call(self, x):
    x = self.conv(x)
    x = self.cong_pool (x)
    return x

model = Sequential()
model .add(Conv2D(filtersen_conv_neurons[0], kernel _sizeek_size, padding=padding,
                  activation=activation))
model .add(MaxPooling2D(pool_sizeepool_size, strides=pool_strides)}
model .add(Conv2D(filtersen_conv_neurons[1], kernel_sise*k_size, padding=padding,
                  activation=activation))
model .add(MaxPooling2D(pool_size=spool size, strides*pool_satrides))
model .add(Conv2D(filters=*n_conv_neurons[2], kernel_sizesk_size, padding=padding,
                  activation=activation))
model .add(MaxPooling2D(pool_size=pool_size, strides=pool_strides))
model .add(Flatten())
model.add({Dense(units=n_dense_neurons[0], activation=activation) )
model .add(Dense(units=n_dense_neurons[1], activation=activation) )
model .add(Dense(units=n_dense_neurons[2], activation=activation) )

model = Sequential()
model.add(MyConv(n_conv_neurons[0]))
model.add(MyConv(n_conv_neurons[1]))
model.add(MyConv(n_conv_neurons[2]))
model.add(Flatten())
model.add({Dense(units=n_dense_neurons[0], activation=activation) )
model.add({Dense(units=n_dense_neurons[1], activation=activation) )
model.add({Dense(units=n_dense_neurons[2], activation='softmax') )

# %% [markdown]
# # Implementation with with Model and Layer Sub-classing

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense

class MyConv(Layer):
  def __init_ (self, n_neuron):
    super(MyConv, self). init_ ()
    self.conv = Conv2D(filtersen_neuron, kernel_sizesk_size, padding=padding,
                        activation =activation)
    self.conv_pool = MaxPooling2D(pool_size=pool_size, strides=pool_strides)
  def call(self, x):
    x = self.conv(x)
    x = self.cong_pool (x)
    return x
class TestCNN(Model):
  def __init__(self):
    super(TestCNN, self).__init__()

    self.conv1 = Myconv(n_conv_neurons[0])
    self.conv2 = Myconv(n_conv_neurons[1])
    self.conv3 = Myconv(n_conv_neurons[2])
  def call(self, x):
      x =self.conv1(x)
      x =self.conv2(x)
      x =self.conv3(x)
      
      x = self.dense1(x)
      x = self.dense2(x)
      x = self.dense3(x)
      return x
